# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv("~/scratch/scaling/d7-extrap/logs/metrics.csv")
df = df[5:]
for i in range(7):
    plt.loglog(df['step'], df[f'inacc_{i}'])
