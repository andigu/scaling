# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("~/scratch/d-anneal/curriculum_d7_to_d9/phase1_d7/logs/metrics.csv")
df['step'] -= df['step'].min()
plt.loglog(df["step"], df["inacc_8"])

df = pd.read_csv("~/scratch/d-anneal/curriculum_d7_to_d9/phase2_d9/logs/metrics.csv")
# df['step'] -= df['step'].min()
plt.loglog(df["step"], df["inacc_8"])

df = pd.read_csv("~/scratch/d-anneal/baseline_d9/baseline_d9/logs/metrics.csv")
# df['step'] -= df['step'].min()
plt.loglog(df["step"], df["inacc_8"])
